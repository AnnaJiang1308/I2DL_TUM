# %% [markdown]
# # Notebook 4: Cifar10 Classification in Pytorch Lightning
#
# In this notebook, we will train an image classifier for the CIFAR-10 dataset, that you already know from exercise 6. Today, however, we will use the PyTorch Lightning framework which makes everything much more convenient!
#
# In case you haven't done yet, you should definitely check out the **PyTorch Lightning Introduction** first!

# %% [markdown]
# ## (Optional) Mount in Google Colab

# %%
# Use the following lines if you want to use Google Colab
# We presume you created a folder "i2dl" within your main drive folder, and put the exercise there.
# NOTE: terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g exercise_07) is given.
# OPTIONAL: Enable GPU via Runtime --> Change runtime type --> GPU

"""
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_07'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
"""

# %% [markdown]
# ### Set up PyTorch environment in colab
#
# For your regular environment this should already have been installed in the previous notebooks.

# %%
# Optional: install correct libraries in google colab
# !python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install tensorboard==2.9.1
# !python -m pip install pytorch-lightning==1.6.0

# %% [markdown]
# ## Imports

# %%
import os
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
import torchvision
import torchvision.transforms as transforms
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Get Device
# In this exercise, we'll use PyTorch Lightning to build an image classifier for the CIFAR-10 dataset. As you know from exercise 06, processing a large set of images is quite computation extensive. Luckily, with PyTorch we're now able to make use of our GPU to significantly speed things up!
#
# In case you don't have a GPU, you can run this notebook on Google Colab where you can access a GPU for free!
#
# Of course, you can also run this notebook on your CPU only - though this is definitely not recommended.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# %% [markdown]
# ## Setup TensorBoard
# In exercise 07 you've already learned how to use TensorBoard. Let's use it again to make the debugging of our network and training process more convenient! Throughout this notebook, feel free to add further logs or visualizations to your TensorBoard!

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs --port 6006

# %% [markdown]
# ## Define your Network
#
# Do you remember the good old times when we used to implement everything in plain numpy? Luckily, these times are over and we're using PyTorch Lightning which makes everything MUCH easier!
#
# Instead of implementing your own model, solver and dataloader, all you have to do is defining a `LightningModule`.
#
# We've prepared the class `exercise_code/MyPytorchModel` for you, that you'll now finalize to build an image classifier with PyTorch Lightning.
#
# ### 0. Dataset & Dataloaders
# Check out the function `prepare_data` of the `CIFAR10DataModule` class that loads the dataset, using the class `torchvision.datasets.ImageFolder` (or the previous `MemoryImageFolder` dataset from exercise 3), which is very similar to the class `ImageFolderDataset` that you implemented earlier!
#
# Implement a **transform** to pre-process the raw data (standardize it and convert it to tensors) and assign it to the variable `my_transform`. Note: On the submission server, the normalization as in the notebook 3 on data augmentation will be performed, so please make sure to use the same normalization! For convenience, we added the precomputed normalization values for you. All normalization you are defining here are tailored to your training.
#
# In pytorch-lightning we could also include the dataset and other classes in our model, but a more reasonable way is to define it outside since it usually is used across multiple projects. If you prefer the all-in-one solution, that is great as well, but here we put it separately.
#
# If you want to improve your performance, you can also perform extensive **data augmentation** here!
#
# Also check out the `DataLoader` class that is used to create  `train_dataloader` and `val_dataloader` and that is very similar to your previous implementation of the DataLoader.
#
# ### 1. Define your model
# Next, let's define your model. Think about a good network architecture. You're completely free here and you can come up with any network you like! (\*)
#
# Have a look at the documentation of `torch.nn` at https://pytorch.org/docs/stable/nn.html to learn how to use use this module to build your network!
#
# Then implement your architecture: initialize it in `__init__()` and assign it to `self.model`. This is particularly easy using `nn.Sequential()` which you only have to pass the list of your layers.
#
# To make your model customizable and support parameter search, don't use hardcoded hyperparameters - instead, pass them as dictionary `hparams` (here, `n_hidden` is the number of neurons in the hidden layer) when initializing `MyPytorchModel`.
#
# Here's an easy example:
#
# ```python
#         self.model = nn.Sequential(
#             nn.Linear(input_size, self.hparams["n_hidden"]),
#             nn.ReLU(),
#             nn.Linear(self.hparams["n_hidden"], num_classes)
#         )
# ```
#
# Have a look at the forward path in `forward(self, x)`, which is so easy, that you don't need to implement it yourself. As PyTorch automatically computes the gradients, that's all we need to do! No need anymore to manually calculate derivatives for the backward paths! :)
#
#
# ____
# \* *The size of your final model must be less than 20 MB, which is approximately equivalent to 5 Mio. params. Note that this limit is quite lenient, you will probably need much less parameters!*
#
# *Also, don't use convolutional layers as they've not been covered yet in the lecture and build your network with fully connected layers (```nn.Linear()```)!*

# %% [markdown]
# ### 2. Training & Validation Step
# Have a look at the functions `training_step` and `validation_step` that take a batch as input and calculate the loss.
#
# ### 3. Optimizer
# Lastly, implement the function `configure_optimizers()` to define your optimizer. Here, the documentation of `torch.optim`at https://pytorch.org/docs/stable/optim.html might be helpful.
#
# That's it! You've now finalized your `LightningModule` which has (at least) the same functionality as your previous numpy-powered image classifier!
#
# Now let's create an instance of your `MyPytorchModel`.

# %%
from exercise_code.MyPytorchModel import MyPytorchModel, CIFAR10DataModule
# make sure you have downloaded the Cifar10 dataset on root: "../datasets/cifar10", if not, please check exercise 03.
hparams = {}

########################################################################
# TODO: Define your hyper parameters here!                             #
########################################################################

hparams = {
    "batch_size": 16,
    "learning_rate": 2e-3,
    "input_size": 1 * 28 * 28,
    "hidden_size": 512,
    "num_classes": 10,
    "num_workers": 2,    # used by the dataloader, more workers means faster data preparation, but for us this is not a bottleneck here
}

pass

########################################################################
#                           END OF YOUR CODE                           #
########################################################################

# Make sure you downloaded the CIFAR10 dataset already when using this cell
# since we are showcasing the pytorch inhering ImageFolderDataset that
# doesn't automatically download our data. Check exercise 3

# If you want to switch to the memory dataset instead of image folder use
# hparams["loading_method"] = 'Memory'
# The default is hparams["loading_method"] = 'Image'
# You will notice that it takes way longer to initialize a MemoryDataset
# method because we have to load the data points into memory all the time.

# You might get warnings below if you use too few workers. Pytorch uses
# a more sophisticated Dataloader than the one you implemented previously.
# In particular it uses multi processing to have multiple cores work on
# individual data samples. You can enable more than workers (default=2)
# via 
# hparams['num_workers'] = 8

# Set up the data module including your implemented transforms
data_module = CIFAR10DataModule(hparams)
data_module.prepare_data()
# Initialize our model
model = MyPytorchModel(hparams)

# %% [markdown]
# Some tests to check whether we'll accept your model:

# %%
from exercise_code.Util import printModelInfo
_ = printModelInfo(model)
# Out:
# FYI: Your model has 1.579 params.
# Model accepted!

# %% [markdown]
# ## Fit Model with Trainer
# Now it's time to train your model.
#
# Have a look of the documentation of `pl.Trainer` at https://pytorch-lightning.readthedocs.io/en/stable/common/trainer.html to find out what arguments you can pass to define your training process.
#
# Then, start the training with `trainer.fit(model)`.

# %%
import pytorch_lightning as pl
trainer = None

########################################################################
# TODO: Define your trainer!                                           #
########################################################################


trainer = pl.Trainer(
    profiler='simple',
    max_epochs=10,
)


########################################################################
#                           END OF YOUR CODE                           #
########################################################################

trainer.fit(model, data_module)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 1.6 M
# -------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.314     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# FIT Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                                    	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                                     	|  -              	|  856987         	|  133.99         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                                                        	|  11.271         	|  10             	|  112.71         	|  84.115         	|
# |  run_training_batch                                                                                                                                                                                        	|  0.0035641      	|  18750          	|  66.827         	|  49.872         	|
# |  [LightningModule]MyPytorchModel.optimizer_step                                                                                                                                                            	|  0.0034208      	|  18750          	|  64.14          	|  47.868         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                                                   	|  0.0011615      	|  18750          	|  21.779         	|  16.253         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                                                              	|  0.0011193      	|  18750          	|  20.987         	|  15.662         	|
# |  on_train_batch_end                                                                                                                                                                                        	|  0.00084147     	|  18750          	|  15.778         	|  11.775         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                                                            	|  0.00098149     	|  6252           	|  6.1363         	|  4.5795         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                                                         	|  0.00054446     	|  6252           	|  3.4039         	|  2.5403         	|
# |  [LightningModule]MyPytorchModel.optimizer_zero_grad                                                                                                                                                       	|  0.00015232     	|  18750          	|  2.8559         	|  2.1314         	|
# |  on_train_batch_start                                                                                                                                                                                      	|  6.2918e-05     	|  18750          	|  1.1797         	|  0.88042        	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                            	|  2.8328e-05     	|  25002          	|  0.70826        	|  0.52857        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_end                 	|  0.01019        	|  10             	|  0.1019         	|  0.076048       	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                                                             	|  0.0081099      	|  11             	|  0.089209       	|  0.066577       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                                                               	|  2.7541e-06     	|  18750          	|  0.05164        	|  0.038539       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                                                              	|  1.7473e-06     	|  18750          	|  0.032762       	|  0.02445        	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                                                             	|  1.7146e-06     	|  18750          	|  0.032149       	|  0.023993       	|
# |  [Callback]TQDMProgressBar.on_batch_end                                                                                                                                                                    	|  1.6816e-06     	|  18750          	|  0.031529       	|  0.02353        	|
# |  [Callback]TQDMProgressBar.on_batch_start                                                                                                                                                                  	|  1.5437e-06     	|  18750          	|  0.028944       	|  0.0216         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_optimizer_step           	|  1.4923e-06     	|  18750          	|  0.027981       	|  0.020882       	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                                                            	|  4.376e-06      	|  6252           	|  0.027359       	|  0.020418       	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                                                        	|  1.3215e-06     	|  18750          	|  0.024777       	|  0.018491       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_zero_grad                	|  1.3033e-06     	|  18750          	|  0.024437       	|  0.018237       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                                                  	|  1.295e-06      	|  18750          	|  0.024281       	|  0.018121       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                                                                	|  1.2371e-06     	|  18750          	|  0.023197       	|  0.017311       	|
# |  [Callback]GradientAccumulationScheduler.on_before_zero_grad                                                                                                                                               	|  1.2144e-06     	|  18750          	|  0.022771       	|  0.016994       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_start                                                                                                                                                    	|  1.2043e-06     	|  18750          	|  0.022581       	|  0.016852       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_backward                 	|  1.1724e-06     	|  18750          	|  0.021983       	|  0.016405       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                                                       	|  3.4756e-06     	|  6252           	|  0.02173        	|  0.016217       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_end                                                                                                                                                      	|  1.1421e-06     	|  18750          	|  0.021415       	|  0.015982       	|
# |  [Callback]GradientAccumulationScheduler.on_before_optimizer_step                                                                                                                                          	|  1.1401e-06     	|  18750          	|  0.021377       	|  0.015954       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                                                 	|  1.1391e-06     	|  18750          	|  0.021358       	|  0.01594        	|
# |  [Callback]ModelSummary.on_batch_end                                                                                                                                                                       	|  1.1387e-06     	|  18750          	|  0.021351       	|  0.015934       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_start                     	|  1.1029e-06     	|  18750          	|  0.020679       	|  0.015433       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_after_backward                  	|  1.1004e-06     	|  18750          	|  0.020632       	|  0.015398       	|
# |  [Callback]ModelSummary.on_batch_start                                                                                                                                                                     	|  1.0964e-06     	|  18750          	|  0.020558       	|  0.015342       	|
# |  [Callback]GradientAccumulationScheduler.on_before_backward                                                                                                                                                	|  1.0944e-06     	|  18750          	|  0.020519       	|  0.015314       	|
# |  [Callback]GradientAccumulationScheduler.on_after_backward                                                                                                                                                 	|  1.0929e-06     	|  18750          	|  0.020491       	|  0.015292       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_end                       	|  1.0849e-06     	|  18750          	|  0.020342       	|  0.015181       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                                                           	|  1.0821e-06     	|  18750          	|  0.020289       	|  0.015142       	|
# |  [LightningModule]MyPytorchModel.on_train_batch_end                                                                                                                                                        	|  7.9493e-07     	|  18750          	|  0.014905       	|  0.011124       	|
# |  [LightningModule]MyPytorchModel.training_step_end                                                                                                                                                         	|  7.6048e-07     	|  18750          	|  0.014259       	|  0.010641       	|
# |  [Strategy]SingleDeviceStrategy.training_step_end                                                                                                                                                          	|  7.4021e-07     	|  18750          	|  0.013879       	|  0.010358       	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                                                                  	|  0.013597       	|  1              	|  0.013597       	|  0.010148       	|
# |  [LightningModule]MyPytorchModel.on_after_backward                                                                                                                                                         	|  6.6489e-07     	|  18750          	|  0.012467       	|  0.0093038      	|
# |  [LightningModule]MyPytorchModel.validation_epoch_end                                                                                                                                                      	|  0.001084       	|  11             	|  0.011925       	|  0.0088992      	|
# |  [LightningModule]MyPytorchModel.on_before_zero_grad                                                                                                                                                       	|  5.8079e-07     	|  18750          	|  0.01089        	|  0.008127       	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                                                       	|  5.4653e-07     	|  18750          	|  0.010247       	|  0.0076476      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_end                                                                                                                                           	|  1.5295e-06     	|  6252           	|  0.0095625      	|  0.0071364      	|
# |  [LightningModule]MyPytorchModel.on_train_batch_start                                                                                                                                                      	|  5.0612e-07     	|  18750          	|  0.0094897      	|  0.0070822      	|
# |  [LightningModule]MyPytorchModel.on_before_backward                                                                                                                                                        	|  4.9808e-07     	|  18750          	|  0.0093391      	|  0.0069697      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_end            	|  1.4706e-06     	|  6252           	|  0.0091941      	|  0.0068615      	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                                                           	|  0.0091384      	|  1              	|  0.0091384      	|  0.0068199      	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                                                          	|  1.3493e-06     	|  6252           	|  0.0084357      	|  0.0062956      	|
# |  [LightningModule]MyPytorchModel.on_before_optimizer_step                                                                                                                                                  	|  4.3929e-07     	|  18750          	|  0.0082367      	|  0.006147       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_start          	|  1.1615e-06     	|  6252           	|  0.0072617      	|  0.0054194      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_start                                                                                                                                         	|  1.1423e-06     	|  6252           	|  0.0071419      	|  0.00533        	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                                                            	|  0.00048912     	|  10             	|  0.0048912      	|  0.0036503      	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                                                               	|  0.00040773     	|  11             	|  0.0044851      	|  0.0033472      	|
# |  [LightningModule]MyPytorchModel.validation_step_end                                                                                                                                                       	|  6.8477e-07     	|  6252           	|  0.0042812      	|  0.003195       	|
# |  [Strategy]SingleDeviceStrategy.validation_step_end                                                                                                                                                        	|  6.2758e-07     	|  6252           	|  0.0039236      	|  0.0029282      	|
# |  [LightningModule]MyPytorchModel.on_validation_batch_end                                                                                                                                                   	|  6.2739e-07     	|  6252           	|  0.0039225      	|  0.0029273      	|
# |  [LightningModule]MyPytorchModel.on_validation_batch_start                                                                                                                                                 	|  5.387e-07      	|  6252           	|  0.003368       	|  0.0025135      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                                                              	|  0.00015372     	|  10             	|  0.0015372      	|  0.0011472      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                                                       	|  0.00084225     	|  1              	|  0.00084225     	|  0.00062857     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                                                                    	|  0.00043258     	|  1              	|  0.00043258     	|  0.00032284     	|
# |  [LightningModule]MyPytorchModel.on_validation_model_train                                                                                                                                                 	|  2.1125e-05     	|  11             	|  0.00023238     	|  0.00017342     	|
# |  [LightningModule]MyPytorchModel.on_validation_model_eval                                                                                                                                                  	|  1.9591e-05     	|  11             	|  0.0002155      	|  0.00016083     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_end                  	|  1.5193e-05     	|  11             	|  0.00016712     	|  0.00012472     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.setup                              	|  7.525e-05      	|  1              	|  7.525e-05      	|  5.6159e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                                                                	|  6.5455e-06     	|  11             	|  7.2001e-05     	|  5.3734e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                                                                  	|  4.7235e-06     	|  11             	|  5.1958e-05     	|  3.8776e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                                                               	|  4.3791e-06     	|  10             	|  4.3791e-05     	|  3.2681e-05     	|
# |  [Callback]TQDMProgressBar.on_epoch_end                                                                                                                                                                    	|  1.8256e-06     	|  21             	|  3.8337e-05     	|  2.8611e-05     	|
# |  [LightningModule]MyPytorchModel.configure_optimizers                                                                                                                                                      	|  3.3875e-05     	|  1              	|  3.3875e-05     	|  2.5281e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_start                                                                                                                                              	|  3.3751e-06     	|  10             	|  3.3751e-05     	|  2.5188e-05     	|
# |  [Callback]TQDMProgressBar.on_epoch_start                                                                                                                                                                  	|  1.5397e-06     	|  21             	|  3.2333e-05     	|  2.413e-05      	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                                                 	|  2.475e-06      	|  10             	|  2.475e-05      	|  1.8471e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                                                         	|  2.2348e-06     	|  11             	|  2.4583e-05     	|  1.8346e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_end                       	|  1.1528e-06     	|  21             	|  2.4208e-05     	|  1.8066e-05     	|
# |  [Callback]ModelSummary.on_epoch_end                                                                                                                                                                       	|  1.1269e-06     	|  21             	|  2.3665e-05     	|  1.7661e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_end                                                                                                                                                      	|  1.1191e-06     	|  21             	|  2.3501e-05     	|  1.7539e-05     	|
# |  [Callback]ModelSummary.on_epoch_start                                                                                                                                                                     	|  1.0634e-06     	|  21             	|  2.2332e-05     	|  1.6666e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_start                     	|  1.0516e-06     	|  21             	|  2.2083e-05     	|  1.648e-05      	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_start                                                                                                                                                    	|  1.0279e-06     	|  21             	|  2.1585e-05     	|  1.6109e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                                                              	|  2.1333e-06     	|  10             	|  2.1333e-05     	|  1.5921e-05     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                                                      	|  1.6791e-05     	|  1              	|  1.6791e-05     	|  1.2531e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_start                                                                                                                                               	|  1.3787e-06     	|  11             	|  1.5166e-05     	|  1.1318e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                                                       	|  1.3258e-06     	|  11             	|  1.4584e-05     	|  1.0884e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                                                            	|  1.2765e-06     	|  11             	|  1.4041e-05     	|  1.0479e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_start                	|  1.2651e-06     	|  11             	|  1.3916e-05     	|  1.0385e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_save_checkpoint                                                                                                                                                	|  1.3625e-06     	|  10             	|  1.3625e-05     	|  1.0168e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_end            	|  1.231e-06      	|  11             	|  1.3541e-05     	|  1.0106e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_end                                                                                                                                           	|  1.2309e-06     	|  11             	|  1.354e-05      	|  1.0105e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_end                                                                                                                                                 	|  1.197e-06      	|  11             	|  1.3167e-05     	|  9.8265e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_save_checkpoint                 	|  1.2542e-06     	|  10             	|  1.2542e-05     	|  9.3601e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                                                       	|  1.25e-05       	|  1              	|  1.25e-05       	|  9.3287e-06     	|
# |  [LightningModule]MyPytorchModel.on_epoch_start                                                                                                                                                            	|  5.8724e-07     	|  21             	|  1.2332e-05     	|  9.2033e-06     	|
# |  [LightningModule]MyPytorchModel.on_epoch_end                                                                                                                                                              	|  5.7738e-07     	|  21             	|  1.2125e-05     	|  9.0489e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_start               	|  1.2123e-06     	|  10             	|  1.2123e-05     	|  9.0474e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                                                                 	|  1.1834e-06     	|  10             	|  1.1834e-05     	|  8.8317e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_start          	|  1.0342e-06     	|  11             	|  1.1376e-05     	|  8.4899e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_end                                                                                                                                                	|  1.1293e-06     	|  10             	|  1.1293e-05     	|  8.4279e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                                                          	|  1.0191e-06     	|  11             	|  1.121e-05      	|  8.366e-06      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_start                                                                                                                                         	|  1.0114e-06     	|  11             	|  1.1125e-05     	|  8.3026e-06     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                                                     	|  1.1125e-05     	|  1              	|  1.1125e-05     	|  8.3026e-06     	|
# |  [LightningModule]MyPytorchModel.on_validation_start                                                                                                                                                       	|  9.8491e-07     	|  11             	|  1.0834e-05     	|  8.0854e-06     	|
# |  [LightningModule]MyPytorchModel.on_validation_end                                                                                                                                                         	|  9.0527e-07     	|  11             	|  9.958e-06      	|  7.4316e-06     	|
# |  [LightningModule]MyPytorchModel.on_train_epoch_end                                                                                                                                                        	|  9.708e-07      	|  10             	|  9.708e-06      	|  7.2451e-06     	|
# |  [LightningModule]MyPytorchModel.on_validation_epoch_end                                                                                                                                                   	|  8.4091e-07     	|  11             	|  9.25e-06       	|  6.9032e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                                                        	|  7.791e-06      	|  1              	|  7.791e-06      	|  5.8144e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_start                                                                                                                                                      	|  7.625e-06      	|  1              	|  7.625e-06      	|  5.6905e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                                                          	|  6.7809e-07     	|  11             	|  7.459e-06      	|  5.5666e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                                                        	|  6.4409e-07     	|  11             	|  7.085e-06      	|  5.2875e-06     	|
# |  [LightningModule]MyPytorchModel.on_validation_epoch_start                                                                                                                                                 	|  6.2873e-07     	|  11             	|  6.916e-06      	|  5.1614e-06     	|
# |  [LightningModule]MyPytorchModel.on_save_checkpoint                                                                                                                                                        	|  6.542e-07      	|  10             	|  6.542e-06      	|  4.8823e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                                                              	|  5.208e-06      	|  1              	|  5.208e-06      	|  3.8867e-06     	|
# |  [LightningModule]MyPytorchModel.on_train_epoch_start                                                                                                                                                      	|  4.875e-07      	|  10             	|  4.875e-06      	|  3.6382e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                                                         	|  3.709e-06      	|  1              	|  3.709e-06      	|  2.768e-06      	|
# |  [Callback]ModelSummary.teardown                                                                                                                                                                           	|  3.583e-06      	|  1              	|  3.583e-06      	|  2.674e-06      	|
# |  [LightningModule]MyPytorchModel.on_fit_end                                                                                                                                                                	|  3.542e-06      	|  1              	|  3.542e-06      	|  2.6434e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.teardown                           	|  3.542e-06      	|  1              	|  3.542e-06      	|  2.6434e-06     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                                                             	|  3.5e-06        	|  1              	|  3.5e-06        	|  2.612e-06      	|
# |  [Callback]GradientAccumulationScheduler.on_fit_end                                                                                                                                                        	|  3.333e-06      	|  1              	|  3.333e-06      	|  2.4874e-06     	|
# |  [Callback]GradientAccumulationScheduler.teardown                                                                                                                                                          	|  3.25e-06       	|  1              	|  3.25e-06       	|  2.4255e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_end                         	|  3.25e-06       	|  1              	|  3.25e-06       	|  2.4255e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                                                           	|  2.875e-06      	|  1              	|  2.875e-06      	|  2.1456e-06     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_start                                                                                                                                                       	|  2.542e-06      	|  1              	|  2.542e-06      	|  1.8971e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                                                                	|  1.959e-06      	|  1              	|  1.959e-06      	|  1.462e-06      	|
# |  [Callback]TQDMProgressBar.on_before_accelerator_backend_setup                                                                                                                                             	|  1.958e-06      	|  1              	|  1.958e-06      	|  1.4612e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_start                     	|  1.875e-06      	|  1              	|  1.875e-06      	|  1.3993e-06     	|
# |  [LightningModule]MyPytorchModel.teardown                                                                                                                                                                  	|  1.875e-06      	|  1              	|  1.875e-06      	|  1.3993e-06     	|
# |  [LightningModule]MyPytorchModel.prepare_data                                                                                                                                                              	|  1.667e-06      	|  1              	|  1.667e-06      	|  1.2441e-06     	|
# |  [LightningModule]MyPytorchModel.configure_callbacks                                                                                                                                                       	|  1.5e-06        	|  1              	|  1.5e-06        	|  1.1194e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_start                       	|  1.417e-06      	|  1              	|  1.417e-06      	|  1.0575e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                                                    	|  1.375e-06      	|  1              	|  1.375e-06      	|  1.0262e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_end                                                                                                                                                      	|  1.292e-06      	|  1              	|  1.292e-06      	|  9.6422e-07     	|
# |  [Callback]TQDMProgressBar.on_configure_sharded_model                                                                                                                                                      	|  1.292e-06      	|  1              	|  1.292e-06      	|  9.6421e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_train_start                                                                                                                                                    	|  1.292e-06      	|  1              	|  1.292e-06      	|  9.6421e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.on_before_accelerator_backend_setup	|  1.25e-06       	|  1              	|  1.25e-06       	|  9.3287e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_start              	|  1.209e-06      	|  1              	|  1.209e-06      	|  9.0227e-07     	|
# |  [Callback]ModelSummary.on_before_accelerator_backend_setup                                                                                                                                                	|  1.208e-06      	|  1              	|  1.208e-06      	|  9.0153e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_start                                                                                                                                             	|  1.208e-06      	|  1              	|  1.208e-06      	|  9.0153e-07     	|
# |  [Callback]GradientAccumulationScheduler.setup                                                                                                                                                             	|  1.167e-06      	|  1              	|  1.167e-06      	|  8.7093e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_end            	|  1.167e-06      	|  1              	|  1.167e-06      	|  8.7093e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                                                                              	|  1.166e-06      	|  1              	|  1.166e-06      	|  8.7018e-07     	|
# |  [Callback]ModelSummary.on_pretrain_routine_start                                                                                                                                                          	|  1.166e-06      	|  1              	|  1.166e-06      	|  8.7018e-07     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_end                                                                                                                                                         	|  1.166e-06      	|  1              	|  1.166e-06      	|  8.7018e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_end                	|  1.166e-06      	|  1              	|  1.166e-06      	|  8.7018e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_configure_sharded_model         	|  1.125e-06      	|  1              	|  1.125e-06      	|  8.3958e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_end                       	|  1.125e-06      	|  1              	|  1.125e-06      	|  8.3958e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_end                                                                                                                                               	|  1.084e-06      	|  1              	|  1.084e-06      	|  8.0899e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_start          	|  1.083e-06      	|  1              	|  1.083e-06      	|  8.0824e-07     	|
# |  [Callback]ModelSummary.on_configure_sharded_model                                                                                                                                                         	|  1.083e-06      	|  1              	|  1.083e-06      	|  8.0824e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_before_accelerator_backend_setup                                                                                                                               	|  1.042e-06      	|  1              	|  1.042e-06      	|  7.7764e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_end                                                                                                                                           	|  1.041e-06      	|  1              	|  1.041e-06      	|  7.769e-07      	|
# |  [Callback]GradientAccumulationScheduler.on_configure_sharded_model                                                                                                                                        	|  1e-06          	|  1              	|  1e-06          	|  7.463e-07      	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_start                                                                                                                                         	|  1e-06          	|  1              	|  1e-06          	|  7.463e-07      	|
# |  [Callback]ModelSummary.on_pretrain_routine_end                                                                                                                                                            	|  1e-06          	|  1              	|  1e-06          	|  7.463e-07      	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                                                               	|  9.58e-07       	|  1              	|  9.58e-07       	|  7.1495e-07     	|
# |  [LightningModule]MyPytorchModel.on_train_end                                                                                                                                                              	|  8.75e-07       	|  1              	|  8.75e-07       	|  6.5301e-07     	|
# |  [LightningModule]MyPytorchModel.on_train_dataloader                                                                                                                                                       	|  8.33e-07       	|  1              	|  8.33e-07       	|  6.2167e-07     	|
# |  [LightningModule]MyPytorchModel.configure_sharded_model                                                                                                                                                   	|  7.91e-07       	|  1              	|  7.91e-07       	|  5.9032e-07     	|
# |  [LightningModule]MyPytorchModel.on_train_start                                                                                                                                                            	|  7.5e-07        	|  1              	|  7.5e-07        	|  5.5972e-07     	|
# |  [LightningModule]MyPytorchModel.setup                                                                                                                                                                     	|  6.67e-07       	|  1              	|  6.67e-07       	|  4.9778e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                                                             	|  6.67e-07       	|  1              	|  6.67e-07       	|  4.9778e-07     	|
# |  [LightningModule]MyPytorchModel.on_fit_start                                                                                                                                                              	|  6.25e-07       	|  1              	|  6.25e-07       	|  4.6644e-07     	|
# |  [LightningModule]MyPytorchModel.on_val_dataloader                                                                                                                                                         	|  6.25e-07       	|  1              	|  6.25e-07       	|  4.6644e-07     	|
# |  [LightningModule]MyPytorchModel.on_pretrain_routine_start                                                                                                                                                 	|  5e-07          	|  1              	|  5e-07          	|  3.7315e-07     	|
# |  [LightningModule]MyPytorchModel.on_pretrain_routine_end                                                                                                                                                   	|  2.92e-07       	|  1              	|  2.92e-07       	|  2.1792e-07     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Now that everything is working, feel free to play around with different architectures. As you've seen, it's really easy to define your model or do changes there.
#
# To pass this submission, you'll need **50%** accuracy.
#
# <div class="alert alert-warning">
#     <h3>Note: Pytorch vs Pytorch-Lightning</h3>
#     <p>At this point you are actually free to submit any pytorch model. A pytorch-lightning model unifies training etc. but it inherently works like a pytorch model when you use `model.forward(blabla)`. For exercise 7 as well as 9-11 you can submit any pytorch model you so desire. In this notebook, we gave you the shell using a pytorch-lightning model since it simplifies everything (i.e., for both you and us on both the code purity as well as the datasets (and, thus, transforms etc.) being part of the model) and you can focus on the notation for now. What you will use later is your own decision and if you prefer to submit pure pytorch code that is cool too! As an exercise for eager people: after submittag and tuning a pytorch-lightning model with the current code, try to submit a pure pytorch version of said code to see what advantages pytorch lightning brings and where you feel you have more control. Good luck!
#     </p>
# </div>

# %% [markdown]
# # Save your model & Report Test Accuracy
#
# When you've done with your **hyperparameter tuning**, have achieved **at least 50% validation accuracy** and are happy with your final model, you can save it here.
#
# Before that, we will check again whether the number of parameters is below 5 Mi and the file size is below 20 MB.
#
# When your final model is saved, we'll lastly report the test accuracy.

# %%
from exercise_code.Util import test_and_save

test_and_save(model, data_module.val_dataloader(), data_module.test_dataloader())
# Out:
# 100%|██████████| 625/625 [00:01<00:00, 370.02it/s]
# Validation Accuracy: 72.07000000000001%
# FYI: Your model has 1.579 params.
# Saving model...
# Checking size...
# Great! Your model size is less than 20 MB and will be accepted :)
# Your model has been saved and is ready to be submitted.
# NOW, let's check the test accuracy:
# 100%|██████████| 1875/1875 [00:03<00:00, 531.67it/s]
# Test Accuracy: 92.15666666666667%

# %% [markdown]
# Congrats! You've now finished your first image classifier in PyTorch Lightning! Much easier than in plain numpy, right? Time to get started with some more complex neural networks - see you at the next exercise!
#
# To create a zip file with your submission, run the following cell:

# %%
from exercise_code.submit import submit_exercise

submit_exercise('../output/exercise07')
# Out:
# relevant folders: ['exercise_code', 'models']
# notebooks files: ['2_tensorboard.ipynb', '4_Cifar10_PytorchLightning.ipynb', '1_pytorch.ipynb', '3_pytorch_lightning.ipynb']
# Adding folder exercise_code
# Adding folder models
# Adding notebook 2_tensorboard.ipynb
# Adding notebook 4_Cifar10_PytorchLightning.ipynb
# Adding notebook 1_pytorch.ipynb
# Adding notebook 3_pytorch_lightning.ipynb
# Zipping successful! Zip is stored under: /Users/hanxijiang/Documents/TUM/22_SS/I2DL/output/exercise07.zip

# %% [markdown]
# # Submission Instructions
#
# Congratulations! You've just built your first image classifier with PyTorch Lightning! To complete the exercise, submit your final model to our submission portal - you probably know the procedure by now.
#
# 1. Go on [our submission page](https://i2dl.dvl.in.tum.de/submission/), register for an account and login. We use your matriculation number and send an email with the login details to the mail account associated. When in doubt, login into tum online and check your mails there. You will get an ID which we need in the next step.
# 2. Log into [our submission page](https://i2dl.dvl.in.tum.de/submission/) with your account details and upload the `zip` file. Once successfully uploaded, you should be able to see the submitted file selectable on the top.
# 3. Click on this file and run the submission script. You will get an email with your score as well as a message if you have surpassed the threshold.
#
# # Submission Goals
#
# - Goal: Successfully implement a a fully connected NN image classifier for CIFAR-10 with PyTorch Lightning
#
# - Passing Criteria: Similar to the last exercise, there are no unit tests that check specific components of your code. The only thing that's required to pass this optional submission, is your model to reach at least **50% accuracy** on __our__ test dataset. The submission system will show you a number between 0 and 100 which corresponds to your accuracy.
#
# - Submission start: __June 21, 2022, 14.00__
# - Submission end: __June 27, 2022, 23.59__
# - You can make **$\infty$** submissions until the end of the semester. Remember that this exercise is an __OPTIONAL SUBMISSION__ and will __not__ be counted for the bonus.

# %% [markdown]
# # [Exercise Review](https://docs.google.com/forms/d/e/1FAIpQLScwZArz6ogLqBEj--ItB6unKcv0u9gWLj8bspeiATrDnFH9hA/viewform)
#
# We are always interested in your opinion. Now that you have finished this exercise, we would like you to give us some feedback about the time required to finish the submission and/or work through the notebooks. Please take the short time to fill out our [review form](https://docs.google.com/forms/d/e/1FAIpQLScwZArz6ogLqBEj--ItB6unKcv0u9gWLj8bspeiATrDnFH9hA/viewform) for this exercise so that we can do better next time! :)
